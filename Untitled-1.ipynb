# %%
from pyKDC101 import KDC
kdc = KDC(SN='27601412')
# Out:
# opening port COM1
# failed at port COM1
# opening port COM2
# failed at port COM2
# opening port COM3

# %%
kdc.get_info()
# Out:
# serial number:		0
# model number:
# firmware version:	0.0.0
# hardware type:		0
# hardware version:	0
# modification state:	0
# number of channels:	0

# %%
kdc.move_abs(1)

# %%
from pylablib.devices import Thorlabs
# List available Thorlabs devices
print(Thorlabs.list_kinesis_devices())
# Out:
# []

# %%
# Connect to the stage using its serial number
stage = Thorlabs.KinesisMotor("27601412")
# Out:
# ---------------------------------------------------------------------------
# D2XXException                             Traceback (most recent call last)
# File c:\Users\Pooja\Documents\GitHub\Three-wave-mixing\twm.venv\Lib\site-packages\pylablib\core\devio\comm_backend.py:809, in FT232DeviceBackend.__init__(self, conn, timeout, term_write, term_read, open_retry_times, datatype, reraise_error)
#     808 try:
# --> 809     self.instr=self._open_instr(port,conn_dict)
#     810     self.opened=True
#
# File c:\Users\Pooja\Documents\GitHub\Three-wave-mixing\twm.venv\Lib\site-packages\pylablib\core\devio\comm_backend.py:821, in FT232DeviceBackend._open_instr(self, port, params)
#     820 if "serial_number" in sig.arg_names: # pyft232 v0.11 signature change
# --> 821     return ft232.Ft232(serial_number=port,**params)
#     822 else:
#
# ...
